# %%
import googlemaps 
import gmaps
import csv
import pickle 
import time
import os
import numpy as np

from datetime import datetime
from googleplaces import GooglePlaces, types, lang
from math import sin, cos, sqrt, atan2, radians
# Anything marked "NEW" is included for generating tf-idf matrices
# need to include googlemaps in requirements
# need to include gmaps in requirements

# %%
def computeDistanceLatLong(lat1, lon1, lat2, lon2):
	"""
	Computes distance between two locations using lat long 

	"""
	# approximate radius of earth in km
	R = 6373.0

	lat1 = radians(lat1)
	lon1 = radians(lon1)
	lat2 = radians(lat2)
	lon2 = radians(lon2)

	dlon = lon2 - lon1
	dlat = lat2 - lat1

	a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
	c = 2 * atan2(sqrt(a), sqrt(1 - a))

	distance = R * c

	return distance

# %%
print(len(review_ids_to_reviews))

# %%
###### START OF NLTK/SVD STUFF ###########

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words = 'english', max_df = .7,
                            min_df = 5)
my_matrix = vectorizer.fit_transform(all_reviews).transpose()

# %%
print(my_matrix.shape)

# %%
from scipy.sparse.linalg import svds
u, s, v_trans = svds(my_matrix, k=50)

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(s[::-1])
plt.xlabel("Singular value number")
plt.ylabel("Singular value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-e5311e057f96> in <module>
# ----> 1 import matplotlib
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 plt.plot(s[::-1])
#
# ImportError: No module named 'matplotlib'

# %%
words_compressed, _, docs_compressed = svds(my_matrix, k=10)
docs_compressed = docs_compressed.transpose()

# %%
print(words_compressed.shape)
print(docs_compressed.shape)

# %%
word_to_index = vectorizer.vocabulary_
index_to_word = {word_to_index[t]:t for t in word_to_index}
print(words_compressed.shape)

# %%
#row normalize
from sklearn.preprocessing import normalize
words_compressed = normalize(words_compressed, axis = 1)

# %%
def closest_words(word_in, k = 10): #k = 338):
    if word_in not in word_to_index: return "Not in vocab."
    sims = words_compressed.dot(words_compressed[word_to_index[word_in],:])
    asort = np.argsort(-sims)[:k+1]
    return [(index_to_word[i],sims[i]/sims[asort[0]]) for i in asort[1:]]

# %%
# Gives you the top 10 words similar to kayak
closest_words("adventure")

# %%
import nltk
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet 
# This is how you get synonyms
syns = wordnet.synsets("aquarium") 
# Seems like this could be useful
print(syns[0])
print(syns[0].definition().split())
print(nltk.pos_tag(syns[0].definition().split()))

# %%
###### END OF NLTK/SVD STUFF ###########

# %%
###### START OF GENERATING SEARCH RESULTS USING TF-IDF ########

# %%
import csv
import os, sys
cwd = os.getcwd()
with open('./places_db.csv', mode='r') as f:
    places = list(csv.DictReader(f))

# %%
# Example of how to get reviews
#initial_reviews = places[0]['reviews'].split("\"")
def trimReviews(initial_reviews):
    initial_reviews = initial_reviews.split("\"")
    unwanted_chars = ["{", "}", ",", "\"", "\'"]
    reviews = initial_reviews
    for entry in reviews:
        if entry in unwanted_chars:
            reviews.remove(entry)
    return reviews

# Example of how to get types
#initial_types = places[0]['types'].split(",")
def trimTypes(initial_types):
    initial_types = initial_types.split(",")
    types = initial_types
    # Remove curly brace from first and last entry
    types[0] = types[0][1:]
    types[-1] = types[-1][:-1]
    
    return types

# %%
all_reviews       = [] # List of string representations of all reviews
all_types         = [] # List of string representations of all types

review_to_places  = {} # Dictionary mapping review_id to the corresponding place 
places_to_details = {} # Places to details about that place
review_id         = 0

# This gives all our data in the correct format
print(trimTypes(places[0]['types']))
for place in places:
    curr_reviews = trimReviews(place['reviews'])
    #curr_types   = trimTypes(place['types'])
    # TODO: (Josh) I think it would be dope
    # if we augmented the types by adding synonyms or similar
    # words to the types - i.e. we should add any plural forms of a word
    # or use stemming to make all the words considered the same
    # 
    # Also might be a good metric to compare the search query words
    # to the types using word embeddings after the fact -- 
    # as of now if our query is "fun family friendly aquatics"
    # we might not get good results related to say aquariums or water parks
    # but if we use word embeddings the results would be solid
    # This would involve using spaCy or some similar library
    # To extract key components from a review (i.e. the root and adjective describing the root)
    # and comparing these to our query (also can use types for this)
    curr_types   = place['types'][1:-1]
    curr_name    = place['name']
    
    place['reviews'] = curr_reviews
    place['types']   = curr_types
    
    places_to_details[curr_name] = place
    
    # we need to store all our reviews to vectorize them
    for review in curr_reviews:
        # This adds the name of the place to the review
        curr_review = review
        curr_review = curr_review + " " + curr_name
        for types in curr_types:
            curr_review = curr_review
        all_reviews.append(curr_review)
        all_types.append(curr_types)
        
        review_to_places[review_id] = curr_name
        review_id += 1
# Out:
# ['amusement_park', 'store', 'point_of_interest', 'food', 'establishment']

# %%
# 1. Need to generate a route and waypoints based on start and end location
# - User should also provide keywords 
# 2. Based on keywords they care about look at reviews and try to find the most closely related document
def generateWaypoints(start_addr, end_addr):
    """
    Generates a route between a start and end address

    Returns an array of waypoints along the route
    """
    rst = []

    gmap = googlemaps.Client(key=os.environ["GOOGLE_KEY"])

    # Request directions via public transit
    now = datetime.now()

    # The locations can be written out or geocoded
    # mode = "driving", "walking", "bicycling", "transit"
    # departure_time -- int or date.datetime
    directions_result = gmap.directions(start_addr,
                                         end_addr,
                                         mode="driving",
                                         departure_time=now)

    # Way to lookup waypoints for later usage
    waypoint_dict = directions_result[0]["legs"][0]["steps"]
    # Use this to determine splits
    trip_distance = directions_result[0]['legs'][0]['distance']['value']
    
    
    total_distance = 0 # total distance in meters
    total_duration = 0 # total duration in seconds

    prev_distance = 0

    waypoints = [] # tuples of (lat, lng)
    polylines = [] # Array of polylines -- can be used for display if we like

    for entry in waypoint_dict:
        total_distance += entry["distance"]["value"]
        total_duration += entry["duration"]["value"]

        # Now we want to include as many waypoints as possible
        # Since computing distance to waypoints is super cheap
        if total_distance - prev_distance > 5000: 
            lat = entry["start_location"]["lat"]
            lng = entry["start_location"]["lng"]
            waypoints.append((lat, lng))
            prev_distance = total_distance
            
        polylines.append(entry["polyline"]["points"])

    return waypoints

# %%
waypoints = generateWaypoints("Ithaca, NY", "Cortland, NY")

# %%
# Now we want a way to generate the distance from each place to the waypoints and we take the minimum of that
def getDistanceToRoute(waypoints, lat, lng):
    """
    Returns the distnace to the route for a given location (takes minimum of waypoints)
    NOTE: This doesn't make any live API calls, it just takes vectors as a relative measurement
    
    Args:
        waypoints - list of waypoints on the path
        lat       - latitude for a given place
        lng       - longitude for a given place 
    """
    min_distance = sys.maxsize
    
    for waypoint in waypoints:
        lat_waypoint = waypoint[0]
        lng_waypoint = waypoint[1]
        distance = computeDistanceLatLong(lat_waypoint, lng_waypoint, lat, lng)
        
        if distance < min_distance:
            min_distance = distance

    return min_distance

# %%
getDistanceToRoute(waypoints, waypoints[0][0], waypoints[0][1])
# Out:
# 0.0

# %%
# At this point we have the distance to each route and all the reviews
# Now given keywords we need to find the most relevant documents

# %%
# First let's build a tfIDF vector based on all of our reviews
vectorizer = TfidfVectorizer(stop_words = 'english', max_df = .7, min_df = 10)
my_matrix = vectorizer.fit_transform(all_reviews).transpose()
my_matrix2 = vectorizer.fit(all_reviews)

# %%
from nltk.tokenize import TreebankWordTokenizer
treebank_tokenizer = TreebankWordTokenizer()

# %%
# We still need to get
# 1. index - inverted index 
# -- def build_inverted_index(msgs): 
# -- DONE
# 2. get idf 
# -- def compute_idf(inv_idx, n_docs, min_df=10, max_df_ratio=0.95):
# -- DONE
# 3. Compute doc_norms
# -- def compute_doc_norms(index, idf, n_docs):
# -- 
# 4. Put it all together in the index
# -- def index_search(query, index, idf, doc_norms, tokenizer=treebank_tokenizer):
# --

# %%
def build_inverted_index(reviews, tokenizer=TreebankWordTokenizer()):
    """ Builds an inverted index from the messages.
    
    Arguments
    =========
    
    revies: array
        Contains every review from the scraped google results
    
    Returns
    =======
    
    inverted_index: dict
        For each term, the index contains 
        a sorted list of tuples (doc_id, count_of_term_in_doc)
        such that tuples with smaller doc_ids appear first:
        inverted_index[term] = [(d1, tf1), (d2, tf2), ...]
        
    Example
    =======
    >> test_idx['be']
    [(0, 2), (1, 2)]
    
    >> test_idx['not']
    [(0, 1)]
    
    """
    # DONT FORGET TO SORT BY DOC_ID (i.e.) first argument
    inverted_index = {}
    doc_id = 0 
    
    # Iterate over all toks
    for review in reviews:
        tokens = tokenizer.tokenize(review)
        tmp_d = {}
        # Iterate over all tokens in the document
        for token in tokens:
            # If the token has never been seen before make an entry
            if token not in tmp_d:
                tmp_d[token] = 0
            tmp_d[token] += 1
        
        # Now we iterate over our temporary dict
        # And add entries into our inverted_index
        for k in tmp_d:
            if k not in inverted_index:
                inverted_index[k] = []
            inverted_index[k].append((doc_id, tmp_d[k]))
        
        doc_id += 1
    
    return inverted_index

# %%
def compute_idf(inv_idx, n_docs, min_df=5, max_df_ratio=0.8):
    """ Compute term IDF values from the inverted index.
    Words that are too frequent or too infrequent get pruned.
    
    Hint: Make sure to use log base 2.
    
    Arguments
    =========
    
    inv_idx: an inverted index as above
    
    n_docs: int,
        The number of documents.
        
    min_df: int,
        Minimum number of documents a term must occur in.
        Less frequent words get ignored. 
        Documents that appear min_df number of times should be included.
    
    max_df_ratio: float,
        Maximum ratio of documents a term can occur in.
        More frequent words get ignored.
    
    Returns
    =======
    
    idf: dict
        For each term, the dict contains the idf value.
        
    """
    
    idf = {}
    # Iterate over all terms in the inv_idx
    for term in inv_idx:
        # Doc frequency
        DF = len(inv_idx[term]) 
        # Throw term away if in fewer than 10 docs
        if DF > 10:
            # Compute idf for term t 
            IDF_t = np.log2(n_docs/(1 + DF))
            
            # Throw term away if it is in more than max_df_ratio of docs
            if DF / n_docs < max_df_ratio:
                idf[term] = IDF_t
    
    return idf

# %%
def compute_doc_norms(index, idf, n_docs):
    """ Precompute the euclidean norm of each document.
    
    Arguments
    =========
    
    index: the inverted index as above
    
    idf: dict,
        Precomputed idf values for the terms.
    
    n_docs: int,
        The total number of documents.
    
    Returns
    =======
    
    norms: np.array, size: n_docs
        norms[i] = the norm of document i.
    """
    # DONT FORGET TO CONVERT TO NUMPY ARRAY
    norms = np.zeros(n_docs)
    
    # Only iterate over valid terms
    for term in idf:
        # This does not change by doc
        curr_idf = idf[term]
        
        for entry in index[term]:
            norms[entry[0]] += (entry[1] * idf[term])**2
    
    # Now normalize each entry 
    for i in range(len(norms)):
        norms[i] = np.sqrt(norms[i])

    return norms

# %%
def index_search(query, index, idf, doc_norms, tokenizer=TreebankWordTokenizer()):
    """ Search the collection of documents for the given query
    
    Arguments
    =========
    
    query: string,
        The query we are looking for.
    
    index: an inverted index as above
    
    idf: idf values precomputed as above
    
    doc_norms: document norms as computed above
    
    tokenizer: a TreebankWordTokenizer
    
    Returns
    =======
    
    results, list of tuples (score, doc_id)
        Sorted list of results such that the first element has
        the highest score, and `doc_id` points to the document
        with the highest score.
    
    Note: 
        
    """
    # How do I get the norm q? I think I just need the term count for the query and compute the norm using the idf
    query = tokenizer.tokenize(query.lower())
   
    #### START GETTING Q norm ####
    q_counts = {}
    q_norm = 0

    # This gives us the term frequency in the query
    for term in query:
        if term in idf:
            if term not in q_counts:
                q_counts[term] = 0
            q_counts[term] += 1

    # This is the sum of the (tf_i * idf_i)**2
    for k in q_counts:
        q_norm += (q_counts[k] * idf[k])**2
        
    
    q_norm = np.sqrt(q_norm)
    
    #### END GETTING Q norm ####
    
    scores = {}
    rst = []
    
    # First iterate over every term
    for term in query:
        if term in idf:
            # Check what docs the query is in 
            term_tups = index[term]
            # q_i: See how many times the term appears in the query
            term_count = q_counts[term]
            for tup in term_tups:
                # This is computing q_i * d_ij
                if tup[0] not in scores:
                    scores[tup[0]] = 0
                scores[tup[0]] += (q_counts[term] * idf[term]) * (tup[1] * idf[term])
    
    # Includes logic in here to divide by norms and such        
    rst = {i : (scores[i] / (q_norm * doc_norms[i])) for i in scores.keys()}
    

    
    return rst

# %%
# The next two cells give us everything we need to inform our final results
# In practice, we can store all of this ahead of time and probably should for the live demo
inv_idx_reviews = build_inverted_index(all_reviews)
idf_reviews     = compute_idf(inv_idx_reviews, len(all_reviews))
doc_norms_reviews = compute_doc_norms(inv_idx_reviews, idf_reviews, len(all_reviews))

inv_idx_types = build_inverted_index(all_types)
idf_types     = compute_idf(inv_idx_types, len(all_types))
doc_norms_types = compute_doc_norms(inv_idx_types, idf_types, len(all_types))

# %%
index_search_rst_reviews = index_search("fun family friendly garden kids not too expensive field trip", inv_idx_reviews, idf_reviews, doc_norms_reviews)
index_search_rst_types = index_search("fun family friendly garden kids not too expensive field trip", inv_idx_types, idf_types, doc_norms_types)

# %%
def computeScores(waypoints, index_search_rst_reviews, index_search_rst_types, 
                  review_to_places, places_to_details):
    """
    Takes scores that we get from our index search against types and reviews and computes
    distances between each place to rank our results
    
    Args:
        waypoints                 - a list of waypoints along the route
        index_search_rst_reviews  - dictionary of review id to tf-idf score of that review against our query
        index_search_rst_types    - dictionary of review id to tf-idf score of types for the place against our query
        review_to_places          - dictionary of review id to name of the corresponding place
        places_to_details         - dictionary of place name to details about that place (i.e. lat/lng, reviews, rating, etc.)
        
    Return:
        Dictionary mapping a place to its score 
    """
    place_distances    = {} # Dictionary mapping place names to the distance to the path
    seen_review_ids    = set() # Set of each seen id so far
    
    # Remember to take EACH review into account
    place_scores_and_counts = {} # Dictionary mapping place names to a tuple of scores and counts for normalization
    
    overlap_ids = set() 
    # NOTE: Here I am just trying to speed things up by looking for overlap 
    # between types and reviews and our query - if the user
    # searches for museum it will show up in types and reviews
    for k in index_search_rst_reviews:
        if k in index_search_rst_types:
            overlap_ids.add(k)
    
    print(overlap_ids)
    
    # We have sufficient reviews with overlapping types
    if len(overlap_ids) > 20:
        for key in overlap_ids:
            curr_place         = review_to_places[key]
            # Here I am just using some arbitrary multiplier to count the reviews more since
            # we know they all have a type included in the query
            curr_score         = ((index_search_rst_reviews[key]*2) + index_search_rst_types[key]) / 2
        
            # This code is for when we have no type overlap but we can omit this for now
            # This is the first review associated with the place
            if curr_place not in place_scores_and_counts:
                place_scores_and_counts[curr_place] = (curr_score, 1)
            else:
                score = place_scores_and_counts[curr_place][0]
                count = place_scores_and_counts[curr_place][1]
                place_scores_and_counts[curr_place] = (score + curr_score, count + 1)

            if curr_place not in place_distances:
                curr_place_details = places_to_details[curr_place]
                curr_lat           = float(curr_place_details['lat'])
                curr_lng           = float(curr_place_details['lng'])
                curr_distance      = getDistanceToRoute(waypoints, curr_lat, curr_lng)

                # This stores the distances - higher score if you are closer
                place_distances[curr_place] =  1 / curr_distance           
    
    # Not enough types in the query 
    else:
        # NOTE: We can include a distance threshold here and throw places out based on distance
        for key in index_search_rst_reviews:
            curr_place         = review_to_places[key]
            curr_score         = index_search_rst_reviews[key]

            # This is the first review associated with the place
            if curr_place not in place_scores_and_counts:
                place_scores_and_counts[curr_place] = (curr_score, 1)
            else:
                score = place_scores_and_counts[curr_place][0]
                count = place_scores_and_counts[curr_place][1]
                place_scores_and_counts[curr_place] = (score + curr_score, count + 1)

            # Ensure we don't double count when checking types
            seen_review_ids.add(key)

            if curr_place not in place_distances:
                curr_place_details = places_to_details[curr_place]
                curr_lat           = float(curr_place_details['lat'])
                curr_lng           = float(curr_place_details['lng'])
                curr_distance      = getDistanceToRoute(waypoints, curr_lat, curr_lng)

                # This stores the distances - higher score if you are closer
                place_distances[curr_place] =  1 / curr_distance
        
        for key in index_search_rst_reviews:
            curr_place         = review_to_places[key]
            curr_score         = index_search_rst_reviews[key] 

            # This is the first review associated with the place
            if curr_place not in place_scores_and_counts:
                place_scores_and_counts[curr_place] = (curr_score, 1)
            else:
                score = place_scores_and_counts[curr_place][0]
                count = place_scores_and_counts[curr_place][1]
                # This prevents double counting of reviews and types
                if key not in seen_review_ids:
                    place_scores_and_counts[curr_place] = (score + curr_score, count + 1)
                else:
                    place_scores_and_counts[curr_place] = (score + curr_score, count)


            if curr_place not in place_distances:
                curr_place_details = places_to_details[curr_place]
                curr_lat           = float(curr_place_details['lat'])
                curr_lng           = float(curr_place_details['lng'])
                curr_distance      = getDistanceToRoute(waypoints, curr_lat, curr_lng)

                # This stores the distances - higher score if you are closer
                place_distances[curr_place] =  1 / curr_distance
        
    final_rst = {} # Mapping of place to final score -- including distance
    for k in place_scores_and_counts:
        score = place_scores_and_counts[k][0]
        count = place_scores_and_counts[k][1]
        
        # TODO: Include distance in our score -- place_distances[k] -- in some way
        final_rst[k] = (score / count)

    return sorted(final_rst.items(), key=lambda kv: kv[1], reverse=True)

# %%
computeScores(waypoints, index_search_rst_reviews, index_search_rst_types, 
                  review_to_places, places_to_details)
# Out:
# set()
# [('Mundy Wildflower Garden', 0.5383667840152903),
#  ('Fairview Park', 0.45599750117658017),
#  ('8th Street Garden', 0.45113654950138793),
#  ('RandM Paintball', 0.3949746527831649),
#  ('Eldred World War II Museum', 0.32260186558750714),
#  ("King's Garden", 0.30712254415753526),
#  ('Harvest View Greenhouses', 0.30589733697926086),
#  ('Can You Escape? LI', 0.28371422155066867),
#  ("Jackson's Garden", 0.2652474391090924),
#  ('Berkshire Gardens Center', 0.26305673144527686),
#  ('Ridgefield Park', 0.26052099640754317),
#  ('Adventures to Peru Tours to Machu Picchu Amazon Kuelap',
#   0.2577172486214536),
#  ('Sandstoner Park', 0.2551677130581171),
#  ('Silver Lake State Park', 0.25236530346172587),
#  ('Sonnenberg Gardens & Mansion State Historic Park', 0.25040960568047305),
#  ('Columbus Park Spray Pad', 0.2455909239212905),
#  ("Ithaca Children's Garden", 0.2447780766467921),
#  ('Glengarry Park', 0.2427238367961393),
#  ('American Museum of Cutlery', 0.2410023352316231),
#  ('Gooseneck Hill Waterfowl Sanctuary', 0.24039661603861315),
#  ('Desperado Plunge', 0.23587521097750444),
#  ('6BC Botanical Garden', 0.2351477901008131),
#  ('Lincoln Park', 0.23273679054636606),
#  ("Hewitt's", 0.22528880771400134),
#  ('Camp JYC', 0.22134956375913822),
#  ('Forked Lake Campground', 0.22065209633266877),
#  ('Altamont Fair', 0.21788656363157588),
#  ('Binghamton Zoo at Ross Park', 0.21770989960117143),
#  ('Circle Line Sightseeing', 0.21285628466619472),
#  ('Bella Viaggi Tours', 0.21247996575426445),
#  ('Whiteface 4x4 Alpine Adventures', 0.21086474548069037),
#  ('Sherkston Shores RV Resort', 0.21006978266133747),
#  ('Mount Greylock State Reservation', 0.20844112768089762),
#  ("Usher's Park Beach", 0.20810111851830682),
#  ('Cutler Botanic Garden', 0.2042003622428031),
#  ('Man in the Van Wine Tours', 0.20379483018577207),
#  ('Taste Harlem Food and Cultural Tours', 0.20110049870430596),
#  ('Ashintully Gardens', 0.2002234917475937),
#  ("Shafer's Tour & Charter", 0.19933356534476193),
#  ('Narrows Botanical Gardens', 0.1981265588150479),
#  ('Berkshire Botanical Garden', 0.19448147429121776),
#  ('Cranford Rose Garden', 0.19314876248334564),
#  ('Bradford Travel Service', 0.1927224183036606),
#  ('Governors Island National Monument', 0.19268180108742897),
#  ('Norman Rockwell Museum', 0.19169289875227816),
#  ('Little Wolf Beach', 0.19160805654699173),
#  ('Blue Water Beach Campground', 0.19046521992887538),
#  ('Top-A-Rise Campground', 0.18958125928476804),
#  ('Silky Jones', 0.18852334271075316),
#  ('Boating with Bob', 0.18839867185987236),
#  ('Potter County Historical Society', 0.18431674584108335),
#  ('Mountain Top Arboretum', 0.1826897560425266),
#  ('Sundrees', 0.18266660150525937),
#  ('Coyle Hill State Forest', 0.18037646030976115),
#  ('Camp Kidura', 0.17922761714690352),
#  ('Camp Prendergast', 0.17770099055026034),
#  ('New York Botanical Garden', 0.17688714642432893),
#  ('Evergreen Cemetery', 0.17628821913177944),
#  ('The Funplex', 0.17574757700283417),
#  ('ADK Aquatics LLC', 0.17566447239389607),
#  ('Kinnear Museum-Local History', 0.174495578721975),
#  ('Cornell Botanic Gardens', 0.17407622293981817),
#  ('Hill 70 Memorial', 0.1739725729158753),
#  ('NYBG Ticket Counter', 0.17364832207421213),
#  ('Brooklyn Botanic Garden', 0.17316920337370284),
#  ('Celtic Tours World Vacations', 0.17312838050520282),
#  ('Clark Botanic Gardens', 0.1726949907051525),
#  ('Glenn H Curtiss Museum', 0.17264152857675782),
#  ("Paul Smith's College VIC", 0.1717764021766178),
#  ('Cold Brook Wildlife Management Area', 0.1715150832710444),
#  ('Corinth Grange', 0.17120225849181786),
#  ('Dinky Doo Petting Zoo', 0.17113301132422565),
#  ('Valentines Place', 0.16953481626573688),
#  ('RMSC Cumming Nature Center', 0.1693820512319329),
#  ('Historical House', 0.16925219019965365),
#  ('Blake McNeil Campgrounds', 0.16871559231105243),
#  ('Sky Zone Trampoline Park', 0.1683143555338286),
#  ('Adventure Sports Rafting Company', 0.16826311461644972),
#  ('Star Trek Original Series Set Tour', 0.1674020253288963),
#  ('Jolly Tours, CWT', 0.1673515961308335),
#  ('Cayuta Lake Camping', 0.1672532885324221),
#  ('Enid A. Haupt Conservatory', 0.1670293003656068),
#  ('Lamoureux Park', 0.16686642489085646),
#  ('The Adventure Center', 0.16680701201979697),
#  ('Lake Placid Boat Tours', 0.16632909819103417),
#  ('House of Frankenstein Wax Museum', 0.1662957549683855),
#  ('K-HOUSE Karaoke Lounge & Suites', 0.16471941739598886),
#  ('Scouts Canada Day Camp DayHondaLahQuah', 0.1643230973314967),
#  ('Dansville ArtWorks', 0.1642767970793642),
#  ('Hillside Motel & Campground', 0.1626690868739208),
#  ('O2togo Dive Centre', 0.1591108471645578),
#  ('Adirondack Park', 0.15909693888985518),
#  ('Sky Zone - New Rochelle, NY', 0.15890954814762592),
#  ('Midway State Park', 0.157717923677654),
#  ('Lake George Beach', 0.15680272086156885),
#  ('Berkshire Vista Resort Inc', 0.15549024927576655),
#  ('The Glass House', 0.15538299234189215),
#  ('Blue Jay Campsite', 0.15491273095225644),
#  ('Botanical Gardens Golf Course', 0.15465358365506898),
#  ('Lamoka Baptist Camp', 0.15402475476563948),
#  ('Cornwall Community Museum & Archives', 0.15267248798343036),
#  ('India Government Tourist Office', 0.15255219423735059),
#  ('Champlin Beach', 0.15246601076833993),
#  ('Parishville park', 0.15176200408567095),
#  ('Franklin D. Roosevelt Boardwalk and Beach', 0.15085818880940785),
#  ('Sourced Adventures', 0.1505849108453128),
#  ('Urban Air Trampoline and Adventure Park', 0.1501629255480631),
#  ('Naumkeag', 0.14994772054615463),
#  ('Trout Ponds Park', 0.14916787668203685),
#  ('Splashwater Kingdom', 0.14915479324995443),
#  ('The Country Place Resort', 0.148820134583461),
#  ('Country Haven Campground', 0.14675573866690356),
#  ('Museum of Sex', 0.14633111436552312),
#  ('Town of Norfolk Museum', 0.1455664584414655),
#  ('Regina A. Quick Center for the Arts', 0.14552626430178878),
#  ('BONOBO Cafe', 0.1454267811864426),
#  ('North Greenbush Dedrick Park', 0.14497676618689911),
#  ('Lake George Escape Campground', 0.14448215561356711),
#  ('Montrose Campground', 0.14357699777169922),
#  ('Ideal Beach', 0.14343269005528492),
#  ('Collins Circle', 0.14333898013096458),
#  ('Onondaga Coach Tours', 0.14321038633551672),
#  ('Bath Beach Park', 0.14277604660575388),
#  ('E-World Travel & Tours 天马旅游', 0.14161131836044813),
#  ('Egyptian Tourist Authority', 0.1415264326062895),
#  ('The New York Pass®', 0.1413927856411097),
#  ('Lake Garfield Beach', 0.1412732163476751),
#  ('Penfield Beach', 0.1410293900152039),
#  ('Moon Tree Design', 0.14069274588765776),
#  ('Amazing Destinations', 0.14066508609907966),
#  ('Cass Park Rink & Pool', 0.14000332184754474),
#  ('Bradley Beach', 0.13925076228584343),
#  ('Bristol Mountain Aerial Adventures', 0.13900749372592783),
#  ('New Jersey Botanical Garden', 0.13861375110067864),
#  ('Old Mill Village', 0.13690341299413353),
#  ('Sunny Hill', 0.13681263261648394),
#  ('Glacier Ice Bar & Lounge', 0.13612008034396006),
#  ('John Davis Gallery', 0.13565917697226199),
#  ('Forness Park', 0.13532279694415908),
#  ('Yankee Trails', 0.13531103241949394),
#  ('Lake Vanare Snowmobile Tours', 0.1350899443269844),
#  ('Savurn Memorials', 0.13501656981960147),
#  ("Everett Children's Adventure Garden", 0.1349498319360416),
#  ('Alps Family Campground Inc', 0.13403565936445874),
#  ('Adirondack Camping Village', 0.1338676738485516),
#  ('Moniuszko Social Club Inc', 0.13377703785467346),
#  ('The New Echo Lake Resort', 0.13375785575226512),
#  ("Peek'n Peak Mountain Adventures", 0.13367049628586877),
#  ('Gray Line New York', 0.133479060905352),
#  ('Breezy Point Campground', 0.1324673042951233),
#  ('Bayville Adventure Park', 0.13243782094513215),
#  ('Adirondack Lakes Center for the Arts', 0.13207133806006074),
#  ('Zinc Bar', 0.1315067441785135),
#  ('Saugerties Village Beach', 0.13148207884083196),
#  ('Bolton Boat Tours and Water Sports on Lake George', 0.13120491949685448),
#  ('Harris Hill Amusement Park', 0.13106328041787554),
#  ('Madagascar, Bronx Zoo', 0.13039152632567563),
#  ('Anchor Inn', 0.12985892305366403),
#  ('Baker Mountain Trail Head', 0.12981608952883303),
#  ('Iroquois Campground', 0.1292179681781484),
#  ('Pine Valley RV Park & Campground', 0.1292007373929038),
#  ('The Fish Hut of New Jersey', 0.12905946284341285),
#  ('USS SLATER', 0.1286658736260203),
#  ('The Fountain at Centennial Park', 0.1286589174256444),
#  ('Onota Lake BEACH', 0.12857457182264959),
#  ('Sandy Beach at Laurel Lake', 0.12823590204457366),
#  ('White Post Farms of Melville', 0.12822885552022414),
#  ('Snug Harbor Cultural Center & Botanical Garden', 0.12820607078670004),
#  ("The Mount, Edith Wharton's Home", 0.12768597920198288),
#  ('Binghamton-Johnson City Mnmnt', 0.12668095202250204),
#  ('The Frame Shop', 0.12637446086373436),
#  ('Jones Pond Mens Only Campground & RV Park', 0.1262904162355066),
#  ('Finger Lakes Visitors Connection', 0.12621033913077323),
#  ('Timequest Mini Golf', 0.12619025542050016),
#  ('Touch Of Texas', 0.1255289151116107),
#  ('Wacky Walks', 0.12517043487514892),
#  ('Berkshire Museum', 0.12511311717734555),
#  ('Frederic Remington Art Museum', 0.12489878208239304),
#  ('Riverside Campground', 0.12418870181370545),
#  ('Lot 10 Bar and Lounge', 0.12412041617785151),
#  ('The Wildlife Conservation and Education Center', 0.1236242945613707),
#  ('Adirondack Flying Services', 0.12359181784425467),
#  ('Iroquois Beach', 0.12328294546487435),
#  ('Dorchester Park', 0.12312091310610299),
#  ('Ecology Village', 0.12295240597504768),
#  ('Compo Beach', 0.12268718099098201),
#  ('Adventure Family Fun Center', 0.12236380203514965),
#  ('Girl Scouts Comstock Adventure Center', 0.12215306494287848),
#  ('Lenox Contra Dance', 0.12183989549504831),
#  ("Hunter's Rock Fall", 0.12164241963021045),
#  ('Raquette Lake Navigation', 0.12151995640215212),
#  ('Lake George / Saratoga KOA', 0.12140527602752568),
#  ('Olga Gallery, Cafe, & Bistro', 0.12140479456862696),
#  ('St. Lawrence Power And Equipment Museum', 0.12130868833339592),
#  ('Jazz Standard', 0.12028192007633584),
#  ('Up Yonda Farm', 0.1201343735620486),
#  ('Hoogs and Crawford Glass', 0.11991113257091546),
#  ('Hang Over Bar', 0.11972959863053613),
#  ('L & S Journeys', 0.11948930807994043),
#  ('Learning Adventure Day Care', 0.11936983437637466),
#  ('A D Titus & Co Monuments', 0.11931373392014934),
#  ('Destination Backcountry Adventures', 0.11908556162849435),
#  ('Bergen County Zoo', 0.11839970555617645),
#  ('Beckley Iron Furnace State Park', 0.11797584088644289),
#  ("Fireman's Firefighting Museum", 0.1167718482511631),
#  ('Kiosk, Marble Bench, Stone Beach', 0.11672365759132178),
#  ('Sycamore Hill Gardens', 0.11664244119386676),
#  ('Luna Park', 0.11637169062904844),
#  ('Airdrenaline Adventure Park', 0.11604354972213825),
#  ('Jones Beach State Park', 0.11589808725156756),
#  ('Field Station: Dinosaurs', 0.11560917822826816),
#  ('Tioga County Historical Society', 0.11545034436557947),
#  ('Riverhurst Park Campground', 0.11530515178677292),
#  ('St Lawrence County Historical Association', 0.11455482422713556),
#  ('Like A Local Tours', 0.11440157003464038),
#  ('5 Wits Albany', 0.11421872777910676),
#  ('Sunset On Seneca Campsites', 0.1142009542215136),
#  ('Seneca Gaming & Entertainment Oil Spring', 0.11418792374630575),
#  ('Berkshire Community College', 0.11399751378344085),
#  ('Upper Canada Campground', 0.11370830472942199),
#  ('Leapin Lizards', 0.11367234321981375),
#  ('Nite Moves', 0.1136401273907065),
#  ('Kanakadea Recreation Area', 0.11354614166271296),
#  ('Pine Crest Campground', 0.11317245782969956),
#  ('EASTERN MEMORIALS', 0.11303199392285301),
#  ('Oakley Corners State Forest', 0.11251672990256488),
#  ('Rubin Museum of Art', 0.1125035223845372),
#  ('Rocks', 0.11211981830577034),
#  ('Cascades Indoor Waterpark', 0.11191077018280915),
#  ('BC BEACH', 0.11170111658742643),
#  ('The River Project Wetlab', 0.1115989614458608),
#  ('Fish Creek Pond Campground', 0.11093128705213268),
#  ('Tubby Tubes Co', 0.11082994584251175),
#  ('Schweinfurth Art Center', 0.11054987776739422),
#  ('The Chalet Waterfront', 0.1105352693906349),
#  ('Triple R Camping Resort and Trailer Sales', 0.11046110341208833),
#  ('Forest Park Carousel Amusement Village', 0.11039224287237254),
#  ('East River State Park', 0.11026974713357063),
#  ('Union Parks & Recreation Department', 0.1102346405939478),
#  ('Botanic Barn Garden Center', 0.11018297155243466),
#  ('Fort William Henry Museum and Restoration', 0.11010914793527538),
#  ('Bowman Lake State Park', 0.1099830783524409),
#  ('Natural Stone Bridge & Caves', 0.10968883421391953),
#  ('Lake George Island Boat Tours', 0.10938003843946784),
#  ('Chapman Historical Museum', 0.10932362968095656),
#  ('Moonwinks', 0.1087612809907367),
#  ("Funa'rama Fun Park", 0.10823287484066899),
#  ('High Peaks Mountain Guides', 0.10819211755344937),
#  ("The Children's Museum of Science and Technology", 0.10765784119729369),
#  ('SLC Arts Gallery at Town Hall', 0.1072660739080955),
#  ('BAYVILLE SCREAM PARK', 0.10666206570419494),
#  ('FirstAir', 0.10633830713420728),
#  ('Gray Line New York Sightseeing', 0.10614357693653224),
#  ('Creation Science Centre', 0.10609303948184128),
#  ('Saranac Lake Village Beach', 0.10593820325626802),
#  ('Art Omi', 0.10585500628231516),
#  ('Adirondack Wilderness Adventures', 0.10578467533137867),
#  ('Farmhouse Snowmobiling', 0.10488443426458101),
#  ('Coney Island Beach', 0.10462817423057735),
#  ('Calf Pasture Beach', 0.10456529335688337),
#  ('T & R Adventure Auto', 0.1045552635370237),
#  ('Funplex Funpark', 0.10430815768140356),
#  ('La Mama Experimental Theatre Club', 0.10430269800030101),
#  ('Deerfoot Lodge', 0.10426697106926985),
#  ('The Point', 0.10398497909728881),
#  ('The Noguchi Museum', 0.10392351615273339),
#  ('Canyon Blaster', 0.10365060388753286),
#  ('Kanakadea Park', 0.10364949277582791),
#  ('Landmark Coffee Shop', 0.10362238136920293),
#  ('C+C Adirondack Snowmobile Tours', 0.10352760297211633),
#  ('Penthouse808', 0.10337725769646583),
#  ('Waneta Lamoka Wildlife Management Area', 0.10299163338279982),
#  ('New York Media Boat / Adventure Sightseeing Tours', 0.10283576984282992),
#  ("Women's Rights National Historical Park", 0.10237551223285846),
#  ('Blue Jay Beach', 0.10219244206096723),
#  ('Pelham Bay Park', 0.10218480222146584),
#  ('Marian Goodman Gallery', 0.10181211338425562),
#  ('The Landmark Tavern', 0.10150845772792844),
#  ('The Maritime Aquarium at Norwalk', 0.10118706614869968),
#  ('Zoom Flume Water Park', 0.10110772475464873),
#  ('Alfred Ceramic Art Museum', 0.10109442518235937),
#  ("McCarthy's Ranch and Campsite, LLC", 0.10108001311226192),
#  ('Moonies Bar & Nightclub', 0.10096430109680292),
#  ('Great Camp Sagamore', 0.10058445598107682),
#  ('Massena Town Beach', 0.10056507933260313),
#  ('Cranberry Lake Campground', 0.10056027935705429),
#  ('Akwesasne Cultural Center, Inc.', 0.10039767137006282),
#  ('Rochester Folk Art Guild', 0.10036966500191241),
#  ('Gateways Inn & Restaurant', 0.10001687754314834),
#  ('Central Hotel', 0.09976157238158655),
#  ('Sunset Beach Lakeside Cottages', 0.09971471755979401),
#  ('Lucky Strike Manhattan', 0.09938434459146298),
#  ("Papa Paul's Seeds", 0.09929952433664856),
#  ('Ithaca Boat Tours', 0.09865871903959392),
#  ('Adirondack Adventures', 0.0986209157275464),
#  ('Corning Museum of Glass', 0.09860164124246197),
#  ('Bowcraft', 0.09842202289785733),
#  ('Philip B. Healey Beach at Florence Avenue', 0.09840294471430222),
#  ('Corners Gallery Contemporary Art / Custom Framing Studio',
#   0.09810375062630071),
#  ('Adirondack Adventure Center', 0.09773383322545474),
#  ('Max Adventures', 0.09770913780023083),
#  ('Hudson New York', 0.09766313469489937),
#  ('Lenox Club', 0.09766191600237993),
#  ('Seward House Museum', 0.0971518653237437),
#  ('Sciencenter', 0.09706459792317301),
#  ("Charlie's Inn Junction Campground", 0.09704753111231379),
#  ('Eighth Lake Campground', 0.09685579751643957),
#  ('Albany Heritage Area Visitors Center', 0.09672730197157459),
#  ('C-A-S-T Audio-Christian DJ', 0.09664272480550536),
#  ('Caneadea Historic Bridge', 0.09633082142630343),
#  ('Adventureland', 0.09628921749282789),
#  ('Lake Placid Public Beach', 0.09618029003315011),
#  ('Event Atlas', 0.09607528170545075),
#  ('Flushing Meadows Corona Park', 0.09606795977458064),
#  ('Ports of New York Winery', 0.09540814301978227),
#  ('Lighthouse Landing Campground', 0.09535293268821415),
#  ('Rogers Rock Campground', 0.09522401147325926),
#  ('Adirondack Adventure Resort', 0.09519421909288395),
#  ('Nickerson Beach Park', 0.09512688806511166),
#  ("Ripley's Believe It or Not! Times Square", 0.0949842528483401),
#  ('Camp Oswego', 0.09490603219664359),
#  ('Bainbridge Memorial Works, Inc.', 0.09455778755884159),
#  ('Brooklyn Unplugged Tours + Graffiti Art', 0.09447422413855239),
#  ("Deno's Wonder Wheel Amusement Park", 0.09413824578284787),
#  ('Lawson Center', 0.09409572992232622),
#  ('Skybrook Campground', 0.09404983058138455),
#  ('Yorker Museum', 0.09365616781331254),
#  ('Buffalo and Erie County Botanical Gardens', 0.09312085082187835),
#  ('Adirondack Saddle Tours', 0.09304204294226458),
#  ('Jennings Beach', 0.09297349752806915),
#  ('Sprayground', 0.09284611770346593),
#  ('Sun Valley Campsites', 0.09274483156386637),
#  ('Madison Square Park', 0.09270334587966839),
#  ('Loews Regency New York', 0.09256874537574616),
#  ('Yonkers Forestry Department', 0.09255291311467179),
#  ('Village Plaza', 0.09228331949397323),
#  ('Roseland Waterpark', 0.09223400422881729),
#  ('Escape Rental Tours', 0.09221155713135679),
#  ('Albany Pine Bush Preserve', 0.09220994678852233),
#  ('SWDesigns', 0.09213370266278308),
#  ('Oakdale Beach', 0.09208795536957899),
#  ("Huck Finn's Playland", 0.09208740641627597),
#  ('The Wild Center', 0.09198278593088352),
#  ('Memorial Park', 0.0919560150704964),
#  ('Thornbush Acres RV Park', 0.0919153756871659),
#  ('Finger Lakes Region State Park Headquarters', 0.09191343657839672),
#  ('Prehistoric World', 0.09183604310866038),
#  ('Long Branch Beach', 0.09181708617472731),
#  ('Runaway Rapids Waterpark', 0.0917938391356104),
#  ('Stony Brook State Park', 0.0916310012015998),
#  ('The Beach Club At Mickey Rats', 0.09141028810462862),
#  ('New York State Museum', 0.09137321766983053),
#  ('Pantheon', 0.09125531097076948),
#  ('Normanskill Preserve East', 0.09109949197476762),
#  ("Kinyon's Canyon", 0.09091418353047204),
#  ('Robert H. Treman State Park', 0.09026068112675042),
#  ('Queens Botanical Garden', 0.0900015850009061),
#  ('Tamarind Tribeca', 0.08990854737904193),
#  ('Jellystone Park of Western New York', 0.08980673629079937),
#  ("Mr. Brown's Pub", 0.08943471457827053),
#  ('Woodlands Beach', 0.08928231045554498),
#  ('Van Saun County Park', 0.08926018141573755),
#  ('Harley Around NYC, LLC.', 0.08878926520929767),
#  ('Tiki Action Park', 0.08876210714693511),
#  ('Pine Cradle Lake Family Campground', 0.08853281852176144),
#  ('Adventure Rooms New Jersey', 0.088472164787468),
#  ('The View', 0.08846220106596725),
#  ('Country Hills Campgrounds', 0.08840706150866304),
#  ('FINGER LAKES WINE RACK TOURS', 0.08835827290161904),
#  ("King Neptune's Pub and Night Club", 0.08797862133226222),
#  ('Brookside Beach', 0.08785420603858154),
#  ('Barnhart Isle Beach', 0.08785178127872535),
#  ('New York City Urban Adventures', 0.08781314234921918),
#  ('Hammond Tours', 0.087748448905506),
#  ('Moffitt Beach', 0.08766241727653253),
#  ('Brook n Wood Family Campground', 0.08756225490323108),
#  ('Level B Bar, Lounge, & Dancing', 0.08723495878058976),
#  ('S & R Underwater', 0.0871650688202843),
#  ('Down To the Felt', 0.08674069827522102),
#  ('Lake Lane Campground', 0.08653850250525917),
#  ('Lake Placid Horse Show', 0.08638919022061405),
#  ('Tracy Camp', 0.08627649588133667),
#  ('Copake Camping Resort', 0.08620712416873258),
#  ('Animal Adventure Park', 0.08614587998044723),
#  ('Crown Point State Historic Site', 0.08570844229337823),
#  ('King Phillips Campground & Resort', 0.08569254651040932),
#  ('Tannery Pond', 0.08563487325033213),
#  ('Clute Park & Campground', 0.08529760739772711),
#  ('48 Lounge', 0.08479474191853228),
#  ('Bailiwick Animal Park and Riding Stables', 0.08435244157864909),
#  ('Time & Space Ltd', 0.0843111535444664),
#  ('Chenango Valley State Park', 0.08427938542071961),
#  ('Riverside-Cedar Campground', 0.08422041040690004),
#  ('Bronx Zoo', 0.08410091284713284),
#  ('McLaren Campground', 0.08407303089830821),
#  ('Lake George RV Park', 0.08357734922687776),
#  ('Camp Archbald', 0.08347633137158596),
#  ('Wilmington Town Beach at Lake Everest', 0.08346617071732874),
#  ('ADK Eagle Flyer Zip Line', 0.08342650556437187),
#  ('Stowe Bay Campground', 0.08314044473972665),
#  ('The Shirt Factory', 0.0831257551422071),
#  ('Staten Island Zoo', 0.08301883735352097),
#  ('Prospect Park Zoo', 0.08278853479914469),
#  ("Roger's Rock Swimming Beach", 0.08255514279101644),
#  ('The Woodlawn Cemetery and Conservancy', 0.08254288583060237),
#  ('GRAN ELÉCTRICA', 0.08232499511228153),
#  ('Brookside Campgrounds', 0.08221392410624556),
#  ('Great Neck Games & Productions', 0.08218981618065514),
#  ('Victorian Gardens Amusement Park', 0.0821824620672858),
#  ('John Boyd Thacher State Park', 0.08209913039308081),
#  ('Event Kings', 0.08198677167886888),
#  ('Tall Pines ATV Park', 0.08181340772802727),
#  ('Pianos', 0.08176009059508146),
#  ('The Beach House Tanning Salon (Bradford)', 0.08170203610477345),
#  ('Evergreen Trails Campgrounds', 0.08162677291535146),
#  ('Keuka Lake State Park', 0.08152035371497424),
#  ('The Spire Theater of Jamestown', 0.08151391453831222),
#  ('La Serre', 0.0814496679497283),
#  ('Watkins Glen / Corning KOA Resort', 0.08135724323860877),
#  ('Maples RV Park', 0.0812466668883081),
#  ('Morocco National Tourist Office', 0.08105388065212836),
#  ('Sugar Creek Glen Campground', 0.08105098270853844),
#  ('Catamount Aerial Adventure Park', 0.08104656723467629),
#  ('Liberty Balloon Co', 0.08104350756534871),
#  ('Sned-Acres Family Campground', 0.0810050430148841),
#  ('Lakeside Campground', 0.08084225526034672),
#  ("Kim's Kids Summer Camp", 0.08079678873070979),
#  ('MVP Basketball Camp', 0.08061203510741795),
#  ('Aperture Foundation', 0.0805268672131754),
#  ('Bully Hill Vineyards', 0.08045045456200973),
#  ('Spruce Row Campsite', 0.08041074501357963),
#  ('Greenwood Hill Farm', 0.08039277719266004),
#  ("O'Toole's Restaurant Pub", 0.08031491009375293),
#  ('Moose Jaw Central', 0.08029360445746672),
#  ('Sunset Boat Charters', 0.07998832832961732),
#  ('October Mountain State Forest', 0.07991417594375515),
#  ('Prospect Lake Park', 0.07971810316827001),
#  ('WildPlay Thacher', 0.0796725074994497),
#  ('Oneida Campground & Lodge', 0.07965064736532534),
#  ('Casinos By M&M', 0.07950032402742048),
#  ('Adventure Bound Camping Resort - Four Winds', 0.0794930100606957),
#  ('Watson Adventures Scavenger Hunts', 0.07921773662010988),
#  ('Queens Zoo', 0.07904297249953132),
#  ('Solomon R. Guggenheim Museum', 0.07879185603271009),
#  ('Letchworth State Park Visitor Center & Museum', 0.07877434223879011),
#  ('Hornell Erie Depot Museum', 0.07838972661945892),
#  ('Chambers Camp and Retreat Center', 0.0782935832284248),
#  ('Lake Placid Toboggan Chute', 0.07818810354729679),
#  ('Panama Rocks Scenic Park', 0.07791200717906897),
#  ('Landmark Diner', 0.07754683956764279),
#  ('Zoological Society of NJ', 0.07748429328644875),
#  ('The Loft', 0.07722857073018717),
#  ('New Museum', 0.07705875528756832),
#  ('Walker Metalsmiths Celtic Jewelry', 0.07688405937495571),
#  ('Adventurers Amusement Park', 0.07674013031028858),
#  ('Manhattan Beach Park', 0.07658816319998754),
#  ('Aurora Balloon Company', 0.0761370381485372),
#  ('Tenement Museum', 0.07606119033943054),
#  ('Critics’ Choice Escape Room NYC - Escape Entertainment NYC',
#   0.07580389380765726),
#  ('Adirondack Experience, the Museum on Blue Mountain Lake',
#   0.07575936757396078),
#  ('Massena Museum', 0.07558360289721391),
#  ('NorthWind Fine Arts', 0.07517853129805985),
#  ('The Museum of Modern Art', 0.0750820240631928),
#  ('Dyker Beach Park', 0.07503049833007423),
#  ('Revolution Rail Co.', 0.07496330717065855),
#  ("Roomer's Night Club", 0.07477030543313326),
#  ('The Pine Hollow Arboretum', 0.07436145339701819),
#  ('Waubeeka Family Campground', 0.07428706309708742),
#  ('LDS Priesthood Restoration Site', 0.07411557354909423),
#  ('Lasting Tributes Monuments LLC', 0.07406101167885465),
#  ("David's Aquariums LLC", 0.07398253079387813),
#  ('Virtual World VR', 0.07391960787048298),
#  ('A Frame Shoppe', 0.07388531047581769),
#  ('Lenox Town Beach', 0.07382934323155257),
#  ('SkyLand Art Barn', 0.07375520334269137),
#  ('Southern Tier Balloon Tours', 0.07371882492186808),
#  ("The People's Beach at Jacob Riis Park", 0.07362252518790618),
#  ('Orchard Beach', 0.07360102868241974),
#  ('Keppel Stone Works', 0.07349944802144222),
#  ('The Frick Collection', 0.073342695011867),
#  ('The Landmark at 57 West', 0.07313219390721094),
#  ('Floodwood Mountain Scout Reservation - Boy Scout High Adventure Camp',
#   0.07311077723741799),
#  ('Chautauqua Institution', 0.07304184355513774),
#  ('Camp Gateway Brooklyn Tamarak and Goldenrod', 0.07252116273444763),
#  ('Charlottenburgh Park', 0.07241751098933728),
#  ('Quest Adventure Gaming', 0.0722355163979102),
#  ("Yono's", 0.07217512906170837),
#  ('Waterloo Harbor Campground', 0.07214013147369902),
#  ('Lewey Lake Campground', 0.07192746227803241),
#  ('WaterHorse Adventures', 0.07186065935157349),
#  ('Lake George Steamboat Company', 0.07178793821433238),
#  ('Washington Park', 0.07165943373653118),
#  ('Wildwood Acres Campground', 0.07157459559830681),
#  ('Jungle World', 0.07149967796038109),
#  ('Yates County History Center', 0.07147597655022658),
#  ('Hidden Pond Campsite', 0.07142073517910327),
#  ('Bement-Billings Farmstead Museum', 0.07127845729852722),
#  ('Frary Funeral Home & Cremation Services', 0.07124541352657673),
#  ('Chautauqua Lake KOA Holiday', 0.07115725193037858),
#  ('Adventure Playground', 0.07080544859959852),
#  ('Ramblewild Adventure Park', 0.07068599892320557),
#  ('Holiday Inn Express Olean', 0.07065023011710334),
#  ('Lake Erie State Park', 0.07059722582945796),
#  ('Old Forge Lake Cruises', 0.07049078552514847),
#  ('Peebles Island State Park', 0.07038267422232204),
#  ('Eight Zero Zero Resto Lounge', 0.0702514766676331),
#  ('Westfield / Lake Erie KOA', 0.06989029165026864),
#  ('Grenville Park Camping & Rv Park', 0.0698656440815737),
#  ('Camp Iroquoina-His Camp Inc', 0.06930077603734702),
#  ('Laurelwood Arboretum', 0.06925127261623946),
#  ('Historic Valley Campground', 0.06922157547989394),
#  ('Central Park', 0.06914126457655112),
#  ('Carl Schurz Park', 0.06907054142890376),
#  ('Dunkirk Historical Museum', 0.06904334675744878),
#  ('Off The Grid', 0.06880886192064119),
#  ('Sylvan Terrace', 0.06876171207716676),
#  ('Taughannock Falls State Park', 0.06876015371643346),
#  ('The Adventure Park at the Discovery Museum', 0.068727206798779),
#  ('The Lowell Hotel', 0.06868284829460156),
#  ('J T Maxies', 0.06838117585970258),
#  ('Family in New York Sightseeing Tours', 0.06833067364622532),
#  ('County Seat Restaurant & Lounge', 0.06787498016041367),
#  ('Seneca Lake State Park', 0.06760060138514916),
#  ('Schuyler Mansion State Historic Site', 0.06745267547641212),
#  ('Alley Pond Park', 0.0672688546906098),
#  ('Silver Creek Optical', 0.06708226372151532),
#  ('One World Observatory', 0.06702815107802872),
#  ('Savoy Mountain State Forest', 0.06696738828540381),
#  ('Beach Home Hardware', 0.06687506675065792),
#  ('Playland Park', 0.06676998259565624),
#  ('Boating With Bob', 0.06655331619183655),
#  ('Triphammer Falls', 0.0665474672885387),
#  ("Pirate's Cove Adventure Golf", 0.066476271160283),
#  ('Sidewalk Food Tours of New York', 0.06643320614671655),
#  ('New York Transit Museum Gallery Annex & Store', 0.06642297132706344),
#  ('Whitney Museum of American Art', 0.06630782391223086),
#  ('Bonnie Brae Cabins & Campsites', 0.06626575294823632),
#  ('Fantasy Forest Amusement Park', 0.06623748857008988),
#  ('Skyland Association', 0.06610558176458775),
#  ('Michaels of Stockbridge', 0.06588038322722001),
#  ('Lakeside General Store and boat rentals', 0.06562563368818998),
#  ('Adirondack Heli Tours', 0.06555696923066151),
#  ('Indian Creek Nature Center', 0.0654238817692652),
#  ('Art Loft', 0.06541479487401174),
#  ('Winewagen Tours', 0.06534972751000484),
#  ('Cardinal / Ottawa South KOA Holiday', 0.06532887142040167),
#  ('Skyline Sightseeing', 0.06527478626286533),
#  ('Martin Van Buren National Historic Site', 0.06523087074856078),
#  ('Lake Placid Visitors Bureau', 0.06520121701163624),
#  ('High Peaks Cyclery', 0.06510698188302103),
#  ('Central Park Zoo', 0.06508928930808985),
#  ('Jewish Community Center MetroWest', 0.0649864391394665),
#  ('Tear Drop Memorial', 0.06492428111229348),
#  ('Inn At Great Neck', 0.06476280724050207),
#  ('I Paddle New York', 0.06474933398188615),
#  ('Ocean Beach Park', 0.064683040440538),
#  ('Homewood Museum', 0.06464570272435362),
#  ('Garnet Mine Tours', 0.06461351399134645),
#  ('Gear For Adventure', 0.06456226060595249),
#  ('Nyack Beach State Park', 0.06452977082199188),
#  ('6 On the Square', 0.06449233947205345),
#  ('205 on Wolf', 0.06447402596078204),
#  ('Madame Tussauds New York', 0.06373785219359848),
#  ('Lake George Bar Crawl', 0.06367155391680837),
#  ('Great Escape Adventures - Board Games & Escape Rooms', 0.06352813876422873),
#  ('Homewood Suites by Hilton Ithaca', 0.06349415973909989),
#  ('Upper Canada Migratory Bird Sanctuary Campground', 0.06336654703008386),
#  ('Robert Louis Stevenson Cottage', 0.06317044444332859),
#  ('TSL Adventures (Kids Crew)', 0.0631550499235674),
#  ('North/South Lake Campground', 0.0630814296605266),
#  ('Long Lake Town Beach', 0.06302819106776202),
#  ('Summit To Stream Adventures', 0.062970981176639),
#  ('Hearthstone Point Campground', 0.06289708852331807),
#  ('Perillo Tours, Inc.', 0.0628524045384625),
#  ('Magic Forest', 0.06269277982518558),
#  ('DAVYDOV MONUMENTS', 0.06263472453994594),
#  ("Madame Oar's", 0.06261672340863886),
#  ('Four Seasons Memorials', 0.062464146071525305),
#  ('Platinum NYC Events Inc.', 0.062134136464885886),
#  ('Camp Gateway - Staten Island', 0.06201820087887865),
#  ('Zippo / Case Museum & Store', 0.06201459314112642),
#  ('Big Flats Community Park', 0.062008586350196425),
#  ('Webster Hall', 0.06182719725866401),
#  ('Great Escape - Six Flags', 0.061667537834786124),
#  ('Dutch Apple Cruises & Tours', 0.061437653553218355),
#  ('Seneca Falls Recreation & Park', 0.061391167617081514),
#  ('Gray Line', 0.06119889215117191),
#  ('Foods of New York Tours', 0.06116046728050634),
#  ('Philly Bar & Lounge', 0.061156801425162846),
#  ('Pioneer Oil Museum of New York', 0.061042863721601746),
#  ('Adirondack Extreme Adventure Course', 0.06080830849947455),
#  ('Turtle Back Zoo', 0.060781989109991774),
#  ('5Pointz', 0.06055843036698885),
#  ('Holiday Inn Express & Suites Gibson', 0.06047233265336044),
#  ('Resorts World Casino New York City', 0.06011023098654616),
#  ('The Great Escape & Splashwater Kingdom', 0.06001711603180239),
#  ('Houghton / Letchworth KOA', 0.05996300210662546),
#  ('Discovery Center of the Southern Tier', 0.059935729791293926),
#  ('Lake George Battleground State Campground', 0.05974056226067623),
#  ("Chautauqua County Fireman's Fraternity in Stockton NY",
#   0.05959153281461423),
#  ('Boundless Adventures - New York City Zipline and Aerial Park',
#   0.05948907580955807),
#  ('Race Brook Lodge', 0.05928535669449754),
#  ('Lake Placid Winter Olympic Museum', 0.058942873768454196),
#  ('City Sightseeing New York', 0.05879494318696385),
#  ('River Road Campgrounds', 0.05864958869207331),
#  ('Jean-Michel Basquiat Commemorative Plaque', 0.058620394541629484),
#  ('Travis Monuments Inc', 0.058617139507971566),
#  ('Recreation Park', 0.05845751581676916),
#  ('Battle Row Campground', 0.058384811240199744),
#  ('Hoffman Pottery-W Stockbridge', 0.05828688933937143),
#  ('Cayuga Nature Center', 0.05820353745414242),
#  ('Moffitt Beach State Campground', 0.05812758348626772),
#  ('Mid-Lakes Navigation', 0.057917377486760444),
#  ('Juniper Woods Campground', 0.05787086031060488),
#  ('Woodlands Camp Ground', 0.05786490005653856),
#  ('Allegheny National Forest Visitors Bureau', 0.057842963752057955),
#  ('del Lago Resort & Casino', 0.05782560277661902),
#  ('Colonial Inn', 0.05781881009338065),
#  ('Brushwood Folklore Center', 0.057788622967613626),
#  ('Indian Lake Islands', 0.0577420924875922),
#  ('Lisbon Town Campground', 0.057677975563465),
#  ("Jake's 58 Hotel & Casino", 0.05766953097683547),
#  ('Museum of the Earth', 0.057655213064209995),
#  ('Packbasket Adventures', 0.05754439705582229),
#  ('La Quinta Inn by Wyndham Binghamton - Johnson City', 0.057532646691001686),
#  ('Black Dog Adventures Fishing Charters', 0.05734107179311144),
#  ('Greystone Nature Preserve', 0.0572370662102001),
#  ('Landmark Tailors & Cleaner', 0.05708643179932637),
#  ('Jones Park', 0.05695063857685253),
#  ('Monument Mountain Motel', 0.056914318341129526),
#  ('The Adventure Park at Long Island', 0.056808063866454074),
#  ("Mary's", 0.056757032413095015),
#  ('Fenton Historical Center', 0.056732303560018266),
#  ('Otsiningo Park', 0.05659289053560404),
#  ('Six Flags Great Escape Lodge & Indoor Waterpark', 0.056274679955893706),
#  ('Schooner Excursions, Inc.', 0.056207342470178355),
#  ('Big Bus Tours New York - Welcome Center', 0.0560308836644972),
#  ('Hillside Campgrounds', 0.0555374622577551),
#  ('Center For Science Teaching And Learning', 0.05546119026241553),
#  ('Lake Harris', 0.055414633370612684),
#  ('Cherry Creek Campgrounds', 0.0553455979738033),
#  ('Nickerson Beach Campground', 0.05526356847921253),
#  ('B Lounge', 0.05525697156656789),
#  ('The Paper Box', 0.055169560059150996),
#  ('R G Ingersoll Museum', 0.05508300532281353),
#  ('Balloons Over Letchworth', 0.055069108489136515),
#  ('American Museum of Natural History', 0.05503892168341798),
#  ('Black Cat Gallery', 0.05501436213669719),
#  ('Adirondacks Jellystone Park', 0.05484923772735003),
#  ('House of Fins', 0.05484634903754471),
#  ('Payless Monuments', 0.054743387546818595),
#  ("Landmark's Spectrum 8 Theatres", 0.054468084167824615),
#  ('Babcock-Hovey BSA Camp', 0.05445248917767866),
#  ('Casagrain Gallery', 0.054317420971264276),
#  ('Ithaca/Tompkins County Convention and Visitors Bureau',
#   0.054290748251903026),
#  ('Genesee Falls Balloon', 0.054222351477687),
#  ('Landmark Square Cafe Inc', 0.05409952804835209),
#  ('Montezuma National Wildlife Refuge', 0.05407520507256549),
#  ('Wade Tours Inc', 0.05391204361570834),
#  ('Putnam Pond Campground', 0.053867842441762105),
#  ('Warrensburg Travel Park', 0.05368026261945785),
#  ('Camp Bell Campground', 0.053619305109438756),
#  ('Mount Washington State Forest', 0.05347801464684204),
#  ("Handwork, Ithaca's Artisan Cooperative", 0.05346950020418399),
#  ('Million Dollar Beach', 0.0534496717520201),
#  ("Lando's Hotel & Lounge", 0.05342629837341214),
#  ('Palisades Climb Adventure Ropes Course', 0.05302249337916459),
#  ('Camp Elmbois', 0.052864464883371154),
#  ('Vine Valley Beach', 0.052754631561341),
#  ('Home Textile Tool Museum', 0.052581374247435815),
#  ('Bennett Beach', 0.05257904126547675),
#  ('Pope Haven Campgrounds LLC', 0.05257265492436856),
#  ("Lyon's Lake", 0.052530096581021556),
#  ('White Pine Camp', 0.0524736377093542),
#  ('The 40/40 Club', 0.05208787019696884),
#  ('Collegiate Village of Potsdam', 0.05196499963661908),
#  ('Science Museum of Long Island', 0.05138569550155761),
#  ('TSL Adventures LLC', 0.05138289067045239),
#  ('Fillmore Glen State Park', 0.05120513635979679),
#  ('Seneca Gaming & Entertainment', 0.051124226535349745),
#  ('West Meadow Beach', 0.05109002772399013),
#  ('PALS Car Service and Wine Tours', 0.05095486551823297),
#  ('Magical Productions Entertainment Inc', 0.05089034007443891),
#  ('Ferenbaugh Campground', 0.05055634004855603),
#  ('Minerva Park & Playground', 0.050470454724270475),
#  ('The Haunt', 0.05028132284609836),
#  ('The SightSeeing Pass NYC', 0.0502074788002926),
#  ('Kingston Monuments Ltd', 0.05019465209093789),
#  ("Frederick's Restaurant & Lng", 0.05017535130455122),
#  ('Pharaoh Lake Wilderness Area', 0.050115360285477514),
#  ('Love is on Lake George Cruises, LLC', 0.05006285283476014),
#  ('Spirit Ballooning', 0.05003728003566671),
#  ('Liberty Harbor RV Park', 0.050035495392077495),
#  ('Absolutely Fish', 0.04999084008771973),
#  ('Camp Chautauqua', 0.049928520068060894),
#  ('Camping Oquaga Creek State Park', 0.049846992763780074),
#  ('Cherry Esplanade', 0.04974999138384873),
#  ('Sacred Root Kava Lounge & Tea Bar', 0.04961680006875909),
#  ('Penn-Plax Pet Products', 0.04957164321729857),
#  ('Castle Clinton National Monument', 0.049448109800538265),
#  ('The Metropolitan Museum of Art', 0.049347258227992616),
#  ('Camp Half Moon', 0.04912727099021347),
#  ('Frisky Otter Tours, Inc.', 0.04895646573155009),
#  ('California Sea Lion Pool', 0.048799082823533076),
#  ("Bill's Vacation Trailers", 0.04875943762359365),
#  ('Lake George Dog Beach', 0.048638451831631305),
#  ('Sake-Tumi', 0.048368536820981745),
#  ('Hancock Shaker Village', 0.04832613517571559),
#  ('Brooklyn Museum', 0.04828533501286715),
#  ('Earlton Hill Family Campgrounds', 0.048271604898478815),
#  ('Landmark on Main Street', 0.04816493484781863),
#  ('Intrepid Sea, Air & Space Museum', 0.04803172154663982),
#  ('Brooklyn Center for the Performing Arts', 0.04801403429526912),
#  ('The Westy', 0.04781144133859298),
#  ('Farran Park Campground & Day-Use', 0.04764616220755313),
#  ('Parasailing Adventures Lake George', 0.04751536179613945),
#  ('Salisbury Chenango Shores', 0.04728518250809405),
#  ('Evangola State Park', 0.047257314307240984),
#  ("Dunn's Boat Service", 0.04719489134486384),
#  ('Newark Valley Depot Museum', 0.0471309326416646),
#  ('Rolling Acres Golf Course and Campground', 0.047006495938692244),
#  ('Akwesasne Mohawk Casino Resort', 0.046768511828396774),
#  ('Washington Square Park', 0.04666118132415879),
#  ('Lakeside Entertainment', 0.046429297905196),
#  ('Lake Placid-North Elba Historical Society', 0.046401953396373596),
#  ('The Cottage B and B', 0.046336030841001574),
#  ('Moffit Beach Campground', 0.04617972184598046),
#  ('Landmark Apartments', 0.04614286606650728),
#  ('6 Flags', 0.046142746103279765),
#  ('Taconic State Park', 0.04585150490590554),
#  ('Lyndhurst Mansion', 0.045686081462348385),
#  ('Brooklyn Bridge Park', 0.045532754791841226),
#  ('Club Shoebox', 0.04547028036200958),
#  ('Liberty Sightseeing', 0.04532370883447453),
#  ('Museum of the Moving Image', 0.04522758209635145),
#  ('Ballooning Adventures', 0.0451591263156553),
#  ("Julie's New. Found. Loved.", 0.045137485505086776),
#  ('A Slice of Brooklyn Bus Tours', 0.04512099896050242),
#  ('The Met Cloisters', 0.04498342970233593),
#  ('TopView Sightseeing', 0.044960045898096664),
#  ('Adirondak Loj & Heart Lake Program Center', 0.044622852288109416),
#  ('Cold Spring Harbor Fish Hatchery & Aquarium', 0.04455151189337006),
#  ('Barrington Stage Company: The Blatt Center', 0.04453895527124027),
#  ('Adventure Transportation Inc', 0.04450831569705563),
#  ('The Hyde Collection', 0.044395598521101164),
#  ('Taste of Troy Food Tours', 0.044387279772161566),
#  ("Hewitt's Garden Centers Queensbury", 0.04358729727940878),
#  ('All Adventures Campground Inc', 0.043448974536712766),
#  ('Rockaway Beach', 0.04335606034373018),
#  ('Sargent Pond Wild Forest', 0.04214969160948641),
#  ('Jon Reis Photography', 0.04196190747694606),
#  ('Devocean Watersports', 0.04183961346277226),
#  ('Stone Art Memorial Co', 0.041630760666085),
#  ("Clark's Beach Motel", 0.04136738342766114),
#  ('Ithaca Falls Natural Area', 0.04129527612884285),
#  ('The Empire Hotel', 0.041274131637058765),
#  ('Prospect Park', 0.04112263759801041),
#  ('Kellystone Park Campsite', 0.04076502862538015),
#  ('37 West Steakhouse & Lounge', 0.04074567261107495),
#  ('Higley Flow State Park', 0.04062772267936963),
#  ('Tack and Go Farms', 0.039798868628587995),
#  ('Route 22 Limousine & Tour Bus Corp.', 0.03942428243742443),
#  ('Coles Creek State Park', 0.03933918667962373),
#  ('Sabattis Adventure Camp', 0.03931504586900608),
#  ('Kaaterskill Falls Viewing Platform', 0.039179929524536514),
#  ('Rock City Park', 0.039124355244924545),
#  ("Locke's Glen on the Lake - Vacation Rentals", 0.0391242080723288),
#  ("McDuff's Pub", 0.038951473593496794),
#  ('Van Vleck House & Gardens', 0.03873643318981809),
#  ('Indoor Extreme Sports Paintball & Laser Tag', 0.038713586563419916),
#  ("The Landmark Loew's Jersey Theatre", 0.03852447829832666),
#  ('Landmark', 0.038461777626460185),
#  ('Sugar Hill Fire Tower', 0.03825272423864885),
#  ('Salt Springs State Park', 0.038075516092057615),
#  ('The Camp at East Lake', 0.03806735548161184),
#  ('20 Railroad Public House', 0.03794359732060443),
#  ('Blueberry Patch Campground', 0.03787465895507848),
#  ('Boy Scouts of America-Cutler', 0.03763177649076008),
#  ('New York Explorer Pass®', 0.037441812780357006),
#  ('Del Motel', 0.03738383178407509),
#  ('West Beach', 0.03668962946720114),
#  ('Just Spas & Adventures', 0.03660586774017452),
#  ('Adventure Calls Outfitters, Inc.', 0.03641540633360229),
#  ('Grapevine Country Tours', 0.0363141233197788),
#  ('Bow Tie Cinemas Landmark', 0.036061234610415015),
#  ('The Morgan Library & Museum', 0.03578892163534336),
#  ('Cornwall', 0.035638958220405303),
#  ('The DL', 0.035535495929890096),
#  ('Golden Beach Campground', 0.03552632350075406),
#  ('Camp Gateway: Wiley Post A', 0.03517481526339687),
#  ('Medusa Tattoo Studio', 0.03517332632365401),
#  ('Orazio Salati Studio & Gallery', 0.03513557606721625),
#  ('Chelsea Landmark', 0.03510271962922374),
#  ('Rancho Pines Campground', 0.03500341680123837),
#  ('Cutco\\Ka-Bar Visitors Center', 0.03488313888548299),
#  ('Abraham Hollander Monuments', 0.03483053172084675),
#  ('Robert Moses State Park', 0.03408371073580003),
#  ('Rockaway Beach Park', 0.03406352864824488),
#  ('Greenwich Point Beach', 0.03396511577510653),
#  ('Warrensburgh Museum of Local History', 0.03395944161010285),
#  ('Blue Note', 0.03392777975926251),
#  ('Albany Institute of History & Art', 0.03363189617321499),
#  ("Saint Peter's Church", 0.03347450797796233),
#  ('The Village Casino', 0.033464612692082514),
#  ('Rollins Pond Campground', 0.033443326146563576),
#  ('Japan Society', 0.0330700398630729),
#  ('Binghamton City Hall', 0.0329306163985835),
#  ('Lost Villages Museum', 0.032928963263313474),
#  ('Tioga Downs Casino Resort', 0.03288880649160489),
#  ('Open Studio', 0.03262536138604506),
#  ('St George-Stanton Funeral Home/St. George Monuments', 0.03260692844090676),
#  ('Casa Mezcal', 0.03196318001798803),
#  ('Sprung Monuments', 0.03191039005727225),
#  ('Arlor Haven Campground', 0.03171722547224315),
#  ('Williams College Museum of Art', 0.031317916908231484),
#  ('TLC Adventures Day Care Inc', 0.03104290085063142),
#  ('Bruggman Fine Art Studio', 0.030903341456636486),
#  ('Sea Hag Soaps & Art Mercantile', 0.03087486685384159),
#  ('Arkwright Hills Campground', 0.030866085267061135),
#  ('Five Spot Soul Food', 0.030841038746375792),
#  ('The Standard', 0.030466521299178415),
#  ('Presby Iris Gardens', 0.030281412422261806),
#  ('Geneva Historical Society', 0.030254639004019528),
#  ('Hickory Hill Family Camping Resort', 0.030145529030304003),
#  ('Lucy Desi Museum', 0.030131187586531386),
#  ("Charmic Limo's & Tours", 0.030092104422430946),
#  ('Norridgewock Hotel', 0.029992743626272966),
#  ('Finger Lakes National Forest', 0.029925491175670612),
#  ('Cherry Lounge', 0.02987740962343802),
#  ('Neue Galerie', 0.02985316795146078),
#  ('Kershaw Park', 0.029674295075434856),
#  ('UFO Monument Park', 0.029544158490872746),
#  ('Brooklyn Bridge Park Pier 5', 0.028959400338121596),
#  ('Louise E. Keir State Wildlife Management Area', 0.02882963530931319),
#  ('Army Navy Air Force Unit # 342', 0.028637661338206277),
#  ('Reg Lenna Center For The Arts', 0.02854954715793752),
#  ('Haviland Cove Beach', 0.028132990478751133),
#  ('Nathaniel Cole Park', 0.02783493550730454),
#  ('Meacham Lake Campground', 0.027785499863979567),
#  ('Upper Canada Village', 0.027170087938515507),
#  ('Lewey Lake Campsite', 0.02683681154775277),
#  ('Lenox Local, LLC.', 0.026646796438691833),
#  ('BluReef Aquarium', 0.026283413732925105),
#  ('Cat and Thomas Mountains Preserves', 0.026032064295800374),
#  ('Circle Line Sightseeing Cruises', 0.025963512592114976),
#  ('Ulysses Historical Society', 0.025665636277973046),
#  ('Central Park Zoo Security', 0.02534940007497226),
#  ('Bloomingdale Bog Hiking Trail', 0.02528579171650812),
#  ('Jacob Riis Park', 0.025187144054278927),
#  ('New York Aquarium', 0.024905510974594175),
#  ('GR8 Lakes Fishing Adventures', 0.02432433679391583),
#  ('Roberson Museum and Science Center', 0.024134178343494243),
#  ('Irving Plaza', 0.0239632707144422),
#  ("DJ's Nite Club", 0.023630080820621853),
#  ('Great Escape Adventures - Ithaca', 0.023559946618824216),
#  ('Rye Playland Beach', 0.02345202619243587),
#  ('Milles Roches Campground', 0.023125485709606094),
#  ('Adventure Scuba Inc', 0.023101054526481174),
#  ('Herbert F. Johnson Museum of Art', 0.023053639064681396),
#  ('James Daniel Entertainment AV Event Lighting Casinos', 0.0226537922063113),
#  ('Urban Cowboy', 0.02234811670924135),
#  ("Dingman's Family Campgrounds", 0.022078741376122233),
#  ('9/11 Tribute Museum', 0.02167928124920829),
#  ('Beartown State Forest', 0.021321043421885212),
#  ('Battery Park', 0.019957880735095433),
#  ('Empire City Casino', 0.01988408599538244),
#  ("Eddie's Aquarium Centre", 0.019285343076307825),
#  ('American Crafts By Robbie Dean', 0.01845300249060931),
#  ('Condor Hotel - Williamsburg, Brooklyn', 0.01126939840236139)]

# %% [markdown]
# ##
